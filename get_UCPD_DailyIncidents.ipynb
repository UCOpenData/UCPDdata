# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
url0 = ('https://incidentreports.uchicago.edu/incidentReportArchive.php?'
        + 'startDate=1583388000&endDate=1614924000&offset=0')

# Get url contents
page0 = requests.get(url0)

# Store contents
soup0 = bs(page0.text, 'lxml')

# Get table data
table_rows0 = soup0.find('table').find_all('tr')

headers0 = [i.text for i in table_rows0[0].find_all(['th'])]

data0 = []

for n in range(240):
    offset = n*5
    
    # Get url
    url = ('https://incidentreports.uchicago.edu/incidentReportArchive.php?'
            + 'startDate=1583388000&endDate=1614924000&offset=' + str(offset))
    
    # Get url contents
    page = requests.get(url)
    
    # Store contents
    soup = bs(page.text, 'lxml')
    
    # Get table data
    table_rows = soup.find('table').find_all('tr')
    
    # Get data
    # find_all = returns a list of bs4 objects by finding tags e.g. <td> .. </td>
    
    data_n = []
    
    for tr in table_rows:
        bs4_list = tr.find_all('td')
        data_list = [bs.text for bs in bs4_list]
        if len(data_list) > 0 and 'Incident' not in data_list[0] and 'Void' not in data_list[0]:
            data_n.append(data_list)
    
    data0 = data0 + data_n

df = pd.DataFrame(data0, columns = headers0)
df
# Out:
#                               Incident  \
# 0                    Non-Criminal Fire
# 1                        Lost Property
# 2                                Theft
# 3                Information / Battery
# 4                  Information / Theft
# ...                                ...
# 1149                             Theft
# 1150  Information / Aggravated Battery
# 1151                Damage to Property
# 1152                     Traffic Crash
# 1153                             Theft
#
#                                           Location         Reported  \
# 0                  5760 S. University (Public Way)   3/5/20 7:06 AM
# 1                           5700 S. Maryland (CCD)  3/5/20 10:56 AM
# 2                                 1346 E. 53rd St.   3/5/20 2:55 PM
# 3     6300 S. University (Woodlawn Charter School)  3/6/20 10:43 AM
# 4                      Kimbark between 54th & 55th  3/6/20 12:58 PM
# ...                                            ...              ...
# 1149                    1414 E. 59th St. (I-House)  2/28/21 4:56 PM
# 1150              6238 S. Park Shore (Parking Lot)  2/28/21 6:55 PM
# 1151                            1200 E. Midway Pl.   3/1/21 8:41 AM
# 1152                              1550 E. 52nd St.  3/1/21 12:45 PM
# 1153                  1554 E. 55th St. (Walgreens)  3/1/21 10:04 PM
#
#                         Occurred  \
# 0                 3/5/20 7:06 AM
# 1     3/1/20 9:00 AM to 10:30 AM
# 2                 3/5/20 2:55 PM
# 3                3/6/20 10:40 AM
# 4      3/5/20 8:00 PM to 8:30 PM
# ...                          ...
# 1149             2/28/21 4:45 PM
# 1150             2/28/21 6:55 PM
# 1151              3/1/21 8:40 AM
# 1152             3/1/21 12:40 PM
# 1153             3/1/21 10:04 PM
#
#                               Comments / Nature of Fire  Disposition  \
# 0     A Facilities Services Bobcat caught fire / Dri...       Closed
# 1     Staff member reports losing laptop computer wh...       Closed
# 2     UCPD officers arrested two suspects for theft ...       Arrest
# 3     During the course of a disagreement, one perso...          CPD
# 4     Wallet taken from unattended, unsecured jacket...          CPD
# ...                                                 ...          ...
# 1149  2 known subjects took a plastic owl from a per...  Ex. Cleared
# 1150  A victim suffered a gun shot wound to the head...          CPD
# 1151  A vehicle involved in a traffic crash struck a...       Closed
# 1152  A UC owned vehicle was struck by another vehic...       Closed
# 1153  Subject took merchandise from off-campus store...       Arrest
#
#            UCPDI#
# 0        20-00175
# 1        20-00176
# 2        20-00177
# 3        20-00178
# 4     2020-014445
# ...           ...
# 1149     21-00116
# 1150  2021-008203
# 1151     21-00117
# 1152     21-00118
# 1153     21-00119
#
# [1154 rows x 7 columns]

# %%
counts = df['Incident'].value_counts()
percent = df['Incident'].value_counts(normalize=True)
pd.DataFrame({'counts': counts, 'percent': percent})
# Out:
#                            counts   percent
# Theft                         372  0.253925
# Lost Property                  94  0.064164
# Theft from Motor Vehicle       94  0.064164
# Burglary                       85  0.058020
# Injured Person                 63  0.043003
# ...                           ...       ...
# Indecent Exposure               1  0.000683
# Obscene Phone Call              1  0.000683
# Attempt Theft from Person       1  0.000683
# Attempt Burglary                1  0.000683
# Security Alarm                  1  0.000683
#
# [133 rows x 2 columns]
